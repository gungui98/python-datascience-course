# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales = pd.read_csv(
    'data/sales_data.csv',
    parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
sales['Customer_Age'].plot(kind='density', figsize=(9,4))
# Out:
# <Axes: ylabel='Density'>

# %%
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', figsize=(10,4), vert=False)
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %%
# Out:
# 11.901659648253654

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
sales['Order_Quantity'].plot(kind='hist', figsize=(10,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(10,4))
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales.sort_values('Year', ascending=False)['Year'].value_counts()
# Out:
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %%
# Out:
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
sales["Year"].value_counts().plot(kind="pie", figsize=(5,5))
# Out:
# <Axes: ylabel='Year'>

# %%
# Out:
# <AxesSubplot:ylabel='Year'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here
sales['Month'].value_counts()
# Out:
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: Month, dtype: int64

# %%
# Out:
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: Month, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales['Month'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
sales['Country'].value_counts().head(1)
# Out:
# United States    39206
# Name: Country, dtype: int64

# %%
# Out:
# United States    39206
# Name: Country, dtype: int64

# %%
# Out:
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: Country, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
sales['Country'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here
sales.loc[:, 'Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
# Out:
# Index(['Water Bottle - 30 oz.', 'Patch Kit/8 Patches', 'Mountain Tire Tube',
#        'AWC Logo Cap', 'Sport-100 Helmet, Red', 'Road Tire Tube',
#        'Sport-100 Helmet, Black', 'Fender Set - Mountain',
#        'Sport-100 Helmet, Blue', 'Touring Tire Tube',
#        ...
#        'Mountain-500 Silver, 44', 'Mountain-500 Silver, 52',
#        'Mountain-100 Black, 42', 'Mountain-100 Silver, 44',
#        'Touring-3000 Blue, 50', 'Mountain-100 Silver, 48',
#        'Mountain-100 Silver, 42', 'Mountain-500 Silver, 48',
#        'Road-650 Red, 52', 'Mountain-500 Black, 52'],
#       dtype='object', length=130)

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here
sales['Product'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(4,4))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
# Out:
# <AxesSubplot:xlabel='Unit_Cost', ylabel='Unit_Price'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Order_Quantity', y='Profit')
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %%
# Out:
# <AxesSubplot:xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here
sales[['Profit', 'Country']].boxplot(by='Country')
# sales.plot(kind='box', subplots=True, x='Order_Quantity', y='Profit')
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %%
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here
sales[['Customer_Age', 'Country']].boxplot(by='Country').set_ylabel('PrCustomer_Agefit')
# Out:
# Text(0, 0.5, 'PrCustomer_Agefit')

# %%
# Out:
# <AxesSubplot:title={'center':'Customer_Age'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
# your code goes here
sales['Calculated_Date'] = sales['Year'].apply(str) + '-' + sales['Month'].apply(str) + '-' + sales['Day'].apply(str)
sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %%
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])
sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %%
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here
sales['Calculated_Date'].plot(figsize=(14,6))
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here
sales.head()
sales['Revenue'] += 50
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France'), 'Order_Quantity'].shape[0]
# Out:
# 25176

# %%
# Out:
# 25176

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks'), 'Order_Quantity'].shape[0]
# Out:
# 104

# %%
# Out:
# 104

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here
state_orders = sales[sales['Country'] == 'France']['State'].value_counts()
state_orders
# Out:
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: State, dtype: int64

# %%
# Out:
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: State, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
state_orders.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here
category_sales = sales['Product_Category'].value_counts()
category_sales
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %%
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
category_sales.plot(kind='pie', figsize=(8,6))
# Out:
# <Axes: ylabel='Product_Category'>

# %%
# Out:
# <AxesSubplot:ylabel='Product_Category'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
# your code goes here
sub_per_acc = sales[sales['Product_Category'] == 'Accessories']['Sub_Category'].value_counts()
sub_per_acc
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %%
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
sub_per_acc.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here
sub_per_bike = sales[sales['Product_Category'] == 'Bikes']['Sub_Category'].value_counts()
sub_per_bike
# Out:
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: Sub_Category, dtype: int64

# %%
# Out:
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: Sub_Category, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
sub_per_bike.plot(kind='pie', figsize=(4,4))
# Out:
# <Axes: ylabel='Sub_Category'>

# %%
# Out:
# <AxesSubplot:ylabel='Sub_Category'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here
sales['Customer_Gender'].value_counts()
# Out:
# M    58312
# F    54724
# Name: Customer_Gender, dtype: int64

# %%
# Out:
# M    58312
# F    54724
# Name: Customer_Gender, dtype: int64

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar', figsize=(8,6))
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
# your code goes here
sales.loc[(sales['Customer_Gender']=='M') & (sales['Revenue']==500)].shape[0]
# Out:
# 50

# %%
# Out:
# 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here
sales.sort_values(by='Revenue', ascending=False).head()
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24       July  2015            52  Adults (35-64)
# 112072 2013-07-24   24       July  2013            52  Adults (35-64)
# 71129  2011-07-08    8       July  2011            22     Youth (<25)
# 70307  2011-04-30   30      April  2011            44  Adults (35-64)
# 70601  2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24       July  2015            52  Adults (35-64)
# 112072 2013-07-24   24       July  2013            52  Adults (35-64)
# 71129  2011-07-08    8       July  2011            22     Youth (<25)
# 70307  2011-04-30   30      April  2011            44  Adults (35-64)
# 70601  2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
# your code goes here
sales.sort_values(by='Revenue', ascending=False).head(1)
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58124      2015-07-24

# %%
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58124      2015-07-24

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
# your code goes here
sales['Order_Quantity'][sales['Revenue']>10000].mean()
# Out:
# 3.689265536723164

# %%
# Out:
# 3.689265536723164

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here
sales['Order_Quantity'][sales['Revenue']<10000].mean()
# Out:
# 11.914539380997528

# %%
# Out:
# 11.914539380997528

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here
sales.loc[(sales['Month']=='May') & (sales['Year']==2016)].shape[0]
# Out:
# 5015

# %%
# Out:
# 5015

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here
sales.loc[(sales['Month'].isin(['May','June','July'])) & (sales['Year']==2016)].shape[0]
# Out:
# 12164

# %%
# Out:
# 12164

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here
sales[['Month', 'Profit']].boxplot(by='Month')
sales[['Profit', 'Month']].boxplot(by='Month')
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %%
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Month]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here
sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
